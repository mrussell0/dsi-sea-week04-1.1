# %%
import requests
import random
import numpy as np
import pandas as pd
import re

word_site = "http://svnweb.freebsd.org/csrg/share/dict/words?view=co&content-type=text/plain"
response = requests.get(word_site)
WORDS = response.content.splitlines()
proper = [word for word in WORDS if word[0].isupper()]
not_proper = [word for word in WORDS if not word[0].isupper()]

class formWords:
    def __init__(self, proper, not_proper):
        self.proper = proper
        self.not_proper = not_proper
        
    def randomProper(self):
        return self.proper[np.random.randint(0,len(self.proper))]
    
    def randomNonProper(self):
        return self.not_proper[np.random.randint(0,len(self.not_proper))]
        
    def randomNumber(self,digits):
        return str(random.sample(range(10 ** (digits - 1), 10 ** (digits)), 1)[0])
    
    def randomPostfix(self):
        postfix = ['Street','Ave', 'Blvd', 'Lane', 'Court']
        return postfix[np.random.randint(1,len(postfix))]
    
    def randomEmailProvider(self):
        provider = ['gmail','yahoo', 'live', 'compuserve', 'aol']
        return provider[np.random.randint(1,len(provider))]
    
    def randomState(self):
        states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]
        return states[np.random.randint(1,len(states))]
        
    def generateText(self, blog_length):
        form = self.getForm()
        blog = []
        for x in range(blog_length):
            choice = np.random.randint(1,50)
            if choice < 38:
                blog += [self.randomNonProper()]
            elif choice < 40:
                blog += [form['email']()]
            elif choice < 44:
                blog += [form['name']()]
            elif choice < 46:
                blog += [form['password']()]
            elif choice < 50:
                blog += [form['address']()]
    
        return " ".join(blog)

    def getForm(self):
        return {
            'email' : lambda : "Email: " + self.randomNumber(4) + self.randomNonProper().lower() + 
                "@" + self.randomEmailProvider() + ".com",
            'name' : lambda : "Name: " + self.randomProper() + " " + self.randomProper(),
            'password' : lambda : "Password: " + self.randomNumber(2) + self.randomNonProper() + 
                self.randomNumber(3) + self.randomProper().lower(),
            'address' : lambda : "Address: " + self.randomNumber(3) + " " + self.randomProper() + 
                " " + self.randomPostfix() + ", " + self.randomProper() + " " + self.randomState() + 
                ", " + self.randomNumber(5),
        }

words = formWords(proper, not_proper)

# %%
print words.getForm()['email']()
print words.getForm()['name']()
print words.getForm()['password']()
print words.getForm()['address']()

#This is the data variable
data = words.generateText(10000)
print data[:100]
# Out:
# Email: 4351aspirate@live.com
# Name: Datsun Starkey
# Password: 17max701manchester
# Address: 244 Everglade Court, Doppler RI, 92100
# thieves dielectric gyrfalcon deprave immature corrosive Address: 846 Staunton Ave, Brenda ND, 11000

# %% [markdown]
# ### Pull all the emails from the data variable

# %%
email = re.findall('[0-9]{4}[a-z]*@[a-z]*.com', data)
email
# Out:
# ['2727totem@live.com',
#  '8351striptease@yahoo.com',
#  '4449breadroot@live.com',
#  '9119ought@aol.com',
#  '8628acropolis@live.com',
#  '5654fact@aol.com',
#  '8596bullseye@compuserve.com',
#  '8075connoisseur@compuserve.com',
#  '2764astonish@yahoo.com',
#  '4925miscreant@aol.com',
#  '7608quiescent@aol.com',
#  '6150mettlesome@compuserve.com',
#  '3089legislate@yahoo.com',
#  '6286plenty@compuserve.com',
#  '4283walkie@yahoo.com',
#  '2910heartrending@live.com',
#  '8549azimuth@live.com',
#  '8427indivisible@compuserve.com',
#  '6152cantilever@aol.com',
#  '6265hasty@yahoo.com',
#  '9435spitz@aol.com',
#  '1043faucet@aol.com',
#  '5829scaup@live.com',
#  '8030khaki@aol.com',
#  '3532appear@compuserve.com',
#  '1607lo@compuserve.com',
#  '1764scruple@aol.com',
#  '9954laminar@yahoo.com',
#  '3290rummage@aol.com',
#  '4232ornament@yahoo.com',
#  '3559gob@live.com',
#  '2200proliferate@aol.com',
#  '2087pee@yahoo.com',
#  '9950gigacycle@yahoo.com',
#  '8493terpsichorean@compuserve.com',
#  '2970hillman@compuserve.com',
#  '2810utopian@yahoo.com',
#  '2120allyl@live.com',
#  '3846modest@aol.com',
#  '1251dynamic@compuserve.com',
#  '5415moment@live.com',
#  '2533inexplicit@live.com',
#  '4059executrix@aol.com',
#  '2521jubilate@aol.com',
#  '4550perjure@aol.com',
#  '2186stillwater@aol.com',
#  '3100imaginate@aol.com',
#  '7294survivor@live.com',
#  '6181ubiquity@yahoo.com',
#  '9369pillar@yahoo.com',
#  '6680barbital@compuserve.com',
#  '1049moiety@compuserve.com',
#  '3011colt@aol.com',
#  '3451shunt@aol.com',
#  '6230susceptible@compuserve.com',
#  '4853forgiven@aol.com',
#  '4043noisemake@aol.com',
#  '8017ad@aol.com',
#  '6133porterhouse@live.com',
#  '7067despond@compuserve.com',
#  '9572marinade@aol.com',
#  '8767friar@live.com',
#  '2844hairpin@aol.com',
#  '2175archive@yahoo.com',
#  '1432osteopathy@compuserve.com',
#  '7917teak@live.com',
#  '6582maitre@compuserve.com',
#  '3231handlebar@live.com',
#  '4476souffle@live.com',
#  '3520rid@aol.com',
#  '4159chummy@aol.com',
#  '5396asymptote@compuserve.com',
#  '1730cinquefoil@aol.com',
#  '3677bathtub@aol.com',
#  '2243peril@compuserve.com',
#  '1901marshy@compuserve.com',
#  '7931confiscate@compuserve.com',
#  '8099pinnate@live.com',
#  '9667reprieve@live.com',
#  '5646detector@live.com',
#  '9192conversation@live.com',
#  '4925beechwood@compuserve.com',
#  '8167schelling@aol.com',
#  '6371softcover@yahoo.com',
#  '6761bloop@aol.com',
#  '1468isochronous@live.com',
#  '8147piteous@yahoo.com',
#  '8373intern@yahoo.com',
#  '7200genotype@live.com',
#  '4777functor@yahoo.com',
#  '2175infelicity@live.com',
#  '1613parapsychology@compuserve.com',
#  '8646toolsmith@aol.com',
#  '6716provocateur@yahoo.com',
#  '1880electronic@compuserve.com',
#  '3782rank@yahoo.com',
#  '5802sabotage@compuserve.com',
#  '4619profane@live.com',
#  '5264specify@live.com',
#  '5425bellflower@aol.com',
#  '4081turnoff@yahoo.com',
#  '5108youngster@compuserve.com',
#  '6192livre@live.com',
#  '6673squabble@yahoo.com',
#  '1359cabal@aol.com',
#  '6372enervate@live.com',
#  '1802cipher@live.com',
#  '7888reminiscent@live.com',
#  '3065orthophosphate@compuserve.com',
#  '4992forwent@yahoo.com',
#  '2447smokescreen@yahoo.com',
#  '8310repulsive@yahoo.com',
#  '5888scythe@live.com',
#  '3302trite@yahoo.com',
#  '3157begrudge@compuserve.com',
#  '5363enforceable@compuserve.com',
#  '3877symptomatic@live.com',
#  '2702crosscut@aol.com',
#  '8340elk@compuserve.com',
#  '4479canister@compuserve.com',
#  '5888trespass@yahoo.com',
#  '7803swamp@compuserve.com',
#  '8059archery@yahoo.com',
#  '7830chestnut@yahoo.com',
#  '2382surcease@live.com',
#  '7158presto@compuserve.com',
#  '7925carbine@live.com',
#  '3611resist@yahoo.com',
#  '6229classificatory@yahoo.com',
#  '9117hollowware@compuserve.com',
#  '3389tectonic@aol.com',
#  '7477quite@compuserve.com',
#  '2353tendency@yahoo.com',
#  '6183inept@yahoo.com',
#  '6712blown@yahoo.com',
#  '5133downbeat@yahoo.com',
#  '6018podia@compuserve.com',
#  '5736perspective@aol.com',
#  '1042transpose@yahoo.com',
#  '1121bank@live.com',
#  '3449broom@live.com',
#  '6433songful@yahoo.com',
#  '8398neutron@aol.com',
#  '5569cultural@yahoo.com',
#  '2658appendices@yahoo.com',
#  '6603hypnotic@compuserve.com',
#  '2138corduroy@live.com',
#  '6191sweatsocks@live.com',
#  '2721deserve@yahoo.com',
#  '1981switchback@live.com',
#  '2710fiance@aol.com',
#  '2688plenary@yahoo.com',
#  '2233otter@aol.com',
#  '6226whim@live.com',
#  '7978maybe@live.com',
#  '2421coleus@aol.com',
#  '6280pollutant@yahoo.com',
#  '4542backbone@compuserve.com',
#  '1804meningitis@yahoo.com',
#  '3293basketball@live.com',
#  '9611sick@compuserve.com',
#  '8756bamboo@compuserve.com',
#  '3293likewise@live.com',
#  '9631cesium@yahoo.com',
#  '2273beak@live.com',
#  '8330true@compuserve.com',
#  '9411glamor@compuserve.com',
#  '9165heal@yahoo.com',
#  '2276proletariat@live.com',
#  '9995eventide@live.com',
#  '3579isomer@live.com',
#  '9824pupil@yahoo.com',
#  '9324belittle@yahoo.com',
#  '2249venerable@live.com',
#  '4424lowboy@yahoo.com',
#  '5050cosponsor@compuserve.com',
#  '9540concubine@aol.com',
#  '4023tune@compuserve.com',
#  '4221turnoff@compuserve.com',
#  '2772normative@live.com',
#  '1878explanation@aol.com',
#  '8301telephoto@yahoo.com',
#  '9901turtleback@compuserve.com',
#  '8788expert@yahoo.com',
#  '2611fictitious@yahoo.com',
#  '6913harmony@compuserve.com',
#  '7594attendee@aol.com',
#  '3817calculate@aol.com',
#  '9293acidic@live.com',
#  '7347embouchure@yahoo.com',
#  '1709seam@live.com',
#  '9581chlorophyll@live.com',
#  '9746sinew@aol.com',
#  '9367bear@compuserve.com',
#  '8784doghouse@yahoo.com',
#  '4118locust@compuserve.com',
#  '2777baffle@aol.com',
#  '1736canticle@live.com',
#  '7132gelatinous@yahoo.com',
#  '2705deletion@aol.com',
#  '9831lick@aol.com',
#  '3588tomb@compuserve.com',
#  '7681marshland@live.com',
#  '8781residuum@yahoo.com',
#  '7950eightieth@aol.com',
#  '2168pollutant@aol.com',
#  '7862disc@aol.com',
#  '1519bedazzle@aol.com',
#  '7397dance@aol.com',
#  '4014headsmen@compuserve.com',
#  '2243militant@compuserve.com',
#  '1559hypochlorite@compuserve.com',
#  '1473impede@aol.com',
#  '9790retardation@yahoo.com',
#  '5610jugate@compuserve.com',
#  '5934coincide@compuserve.com',
#  '8215pamphlet@compuserve.com',
#  '4615bull@yahoo.com',
#  '5320summertime@live.com',
#  '2503artifice@compuserve.com',
#  '8054plagioclase@yahoo.com',
#  '9695premium@compuserve.com',
#  '2488gelable@live.com',
#  '8456cautious@compuserve.com',
#  '8207impost@aol.com',
#  '1866spontaneous@compuserve.com',
#  '4837halogen@compuserve.com',
#  '6686amanuensis@compuserve.com',
#  '7885loquat@aol.com',
#  '4662indestructible@live.com',
#  '6968love@aol.com',
#  '1961fiftyfold@yahoo.com',
#  '7654incomputable@compuserve.com',
#  '5170tempt@yahoo.com',
#  '1425grata@aol.com',
#  '2414mid@live.com',
#  '3402guise@compuserve.com',
#  '8494approximant@live.com',
#  '4997dissertation@compuserve.com',
#  '1990manna@aol.com',
#  '9033raptor@yahoo.com',
#  '2496hotbed@yahoo.com',
#  '6768collimate@yahoo.com',
#  '8426rose@aol.com',
#  '7199scarecrow@compuserve.com',
#  '4754servicemen@yahoo.com',
#  '3460crouch@yahoo.com',
#  '9180acidulate@yahoo.com',
#  '4281aphasic@live.com',
#  '7710masseur@compuserve.com',
#  '3852negotiate@yahoo.com',
#  '3638downbeat@live.com',
#  '7361patristic@yahoo.com',
#  '2629sheathe@aol.com',
#  '1043soapsud@yahoo.com',
#  '5268allay@compuserve.com',
#  '6504queasy@live.com',
#  '9588polar@live.com',
#  '5503middlemen@aol.com',
#  '5644spacious@compuserve.com',
#  '8369barbiturate@live.com',
#  '7637journeymen@yahoo.com',
#  '8849godparent@live.com',
#  '7144venerable@yahoo.com',
#  '1891peninsula@compuserve.com',
#  '1747serviceberry@yahoo.com',
#  '1352locknut@yahoo.com',
#  '7649next@aol.com',
#  '7026religion@live.com',
#  '4475pus@live.com',
#  '9567indirect@aol.com',
#  '5091aphrodisiac@live.com',
#  '7703radices@compuserve.com',
#  '3445estop@aol.com',
#  '8839mung@aol.com',
#  '7358rondo@yahoo.com',
#  '9518sunflower@compuserve.com',
#  '1954geld@yahoo.com',
#  '4600show@yahoo.com',
#  '5931this@live.com',
#  '5142trait@live.com',
#  '1914rubric@yahoo.com',
#  '9910chaperon@aol.com',
#  '2092cheesemaking@yahoo.com',
#  '9451wispy@yahoo.com',
#  '5862apache@compuserve.com',
#  '9628estrous@yahoo.com',
#  '3092regressive@aol.com',
#  '9851honorarium@yahoo.com',
#  '3149sorption@yahoo.com',
#  '7436tractor@aol.com',
#  '9818brookside@live.com',
#  '4209mad@compuserve.com',
#  '1461tide@aol.com',
#  '7711glycerine@yahoo.com',
#  '6391toward@aol.com',
#  '4126mussel@live.com',
#  '1746oceanography@compuserve.com',
#  '8109wishbone@live.com',
#  '4793but@aol.com',
#  '5623horsemen@compuserve.com',
#  '6511horseshoe@aol.com',
#  '1639chartroom@aol.com',
#  '3984gassy@compuserve.com',
#  '5452cellophane@live.com',
#  '8897tribal@compuserve.com',
#  '2213nuclear@compuserve.com',
#  '6035knoweth@live.com',
#  '6852palmate@aol.com',
#  '5577obligate@compuserve.com',
#  '8756thrust@compuserve.com',
#  '4863marionette@live.com',
#  '3906singleton@yahoo.com',
#  '9546downwind@yahoo.com',
#  '4224austere@aol.com',
#  '4846formidable@live.com',
#  '3522excelling@aol.com',
#  '2107feed@yahoo.com',
#  '9018coronate@live.com',
#  '8952maladaptive@compuserve.com',
#  '5741mimosa@compuserve.com',
#  '8368wino@live.com',
#  '5344adolescent@live.com',
#  '4591album@live.com',
#  '7959hereunto@compuserve.com',
#  '1229erudition@compuserve.com',
#  '3001divine@aol.com',
#  '2445inquire@compuserve.com',
#  '2873iris@compuserve.com',
#  '2075doggone@yahoo.com',
#  '5443thrown@yahoo.com',
#  '9011quadratic@yahoo.com',
#  '9070trust@live.com',
#  '1802pistol@aol.com',
#  '4708loris@live.com',
#  '2459belly@live.com',
#  '9262confidential@live.com',
#  '7737t@live.com',
#  '3623several@yahoo.com',
#  '8952tattle@live.com',
#  '5943wont@aol.com',
#  '1651shoulder@aol.com',
#  '3724yield@yahoo.com',
#  '3248borax@live.com',
#  '5748abalone@live.com',
#  '8705ala@compuserve.com',
#  '9468electronic@yahoo.com',
#  '5300iterate@aol.com',
#  '8755viceroy@live.com',
#  '2537cilia@aol.com',
#  '3050mouth@yahoo.com',
#  '4860heavyweight@yahoo.com',
#  '8187seamstress@yahoo.com',
#  '4433urania@live.com',
#  '9232parody@live.com',
#  '9629guaranteeing@live.com',
#  '2028inalienable@live.com',
#  '2035affirmation@live.com',
#  '7944sightseeing@yahoo.com',
#  '7278barony@aol.com',
#  '6240immaculate@compuserve.com',
#  '3218confound@live.com',
#  '8327trifle@aol.com',
#  '2490planetoid@live.com',
#  '4763cyclone@live.com',
#  '4294squirmy@live.com',
#  '2395sandblast@compuserve.com',
#  '5180falsetto@compuserve.com',
#  '1755incapable@live.com',
#  '9092midmorn@yahoo.com',
#  '3466conjunct@compuserve.com',
#  '8517teahouse@live.com',
#  '7864starboard@live.com',
#  '4445genie@aol.com',
#  '9456deerskin@aol.com',
#  '1986cavort@aol.com',
#  '5924chink@compuserve.com',
#  '7646variate@yahoo.com',
#  '9110assist@aol.com',
#  '2557tussock@live.com',
#  '6153organdy@live.com',
#  '6258servitor@live.com',
#  '6209loosen@live.com',
#  '2816monotreme@yahoo.com',
#  '2865utensil@aol.com',
#  '2580umbilical@live.com',
#  '8936rangeland@yahoo.com',
#  '8965contradistinguish@live.com',
#  '8182sofa@compuserve.com',
#  '1066postprocess@live.com',
#  '9184where@compuserve.com',
#  '2872hospitable@compuserve.com',
#  '7480populous@yahoo.com',
#  '3888ecumenic@aol.com',
#  '1381vertex@compuserve.com',
#  '9756workbench@live.com',
#  '2591moist@compuserve.com',
#  '1697climatology@aol.com',
#  '2626amoeboid@live.com',
#  '4217twist@compuserve.com',
#  '4357chit@aol.com',
#  '6039motivate@yahoo.com',
#  '5010drench@yahoo.com',
#  '3307dad@yahoo.com',
#  '2737premier@aol.com',
#  '3933newspapermen@aol.com',
#  '8602season@compuserve.com',
#  '4153tentacle@live.com',
#  '3111wove@yahoo.com']

# %% [markdown]
# ### Pull all the names from the data variable

# %%
name = re.findall('Name: (\w* \w*)', data)
name
# Out:
# ['Schofield Mennonite',
#  'Geoffrey Rhodesia',
#  'Carlyle Octavia',
#  'Albuquerque Floridian',
#  'Gunderson Yalta',
#  'Alec Addressograph',
#  'Ezra Spanish',
#  'Camelot Hollingsworth',
#  'Minerva Episcopalian',
#  'Bloch Pavlovian',
#  'Agee Andre',
#  'Sutton Allentown',
#  'Browne Barbour',
#  'Norfolk Atwood',
#  'Hershel Mafioso',
#  'Adlerian Croix',
#  'Montana Catherwood',
#  'Simmons Timex',
#  'Porto Troutman',
#  'Blackwell Boeing',
#  'Eldon Lind',
#  'Lauren Hudson',
#  'Tess Ares',
#  'Lenny Charley',
#  'Andy Layton',
#  'Kerr Malaysia',
#  'Russo Esther',
#  'Elkhart Ukraine',
#  'Byronic McDaniel',
#  'Walcott Salesian',
#  'Sandusky Abram',
#  'Dumpty Gruyere',
#  'Barnabas Winifred',
#  'Slavonic Moses',
#  'Shapiro Lund',
#  'Brennan WAC',
#  'Felice Gatlinburg',
#  'Wadsworth McGregor',
#  'Jason Pompeii',
#  'Prescott Juno',
#  'Zanzibar Kentucky',
#  'Tutenkhamon Tampa',
#  'Seymour AC',
#  'Goddard Marcy',
#  'Nostrand Argus',
#  'Catalonia Ares',
#  'Fuchsia Canada',
#  'Rigel Conrail',
#  'Hermes Whittaker',
#  'Cyanamid Vanderbilt',
#  'Ethel Indoeuropean',
#  'Gino Patti',
#  'Orwell Hawley',
#  'Katowice Marlborough',
#  'Colgate Agee',
#  'McKee Frye',
#  'Manville Ziegler',
#  'Whippany Mercedes',
#  'Bach Clarence',
#  'Bethlehem Indianapolis',
#  'Zealand Kettering',
#  'NCR Erich',
#  'Pasteur Groton',
#  'Alcestis Mohammedan',
#  'Britannica Aitken',
#  'Farnsworth AR',
#  'Olympia Pulaski',
#  'Vietnam Jacobson',
#  'Gorky Marguerite',
#  'Eurydice Lorenz',
#  'Granville Pittston',
#  'Davies Feldman',
#  'McGowan Calhoun',
#  'Starr Shearer',
#  'Sheldon Clare',
#  'Hyde Orkney',
#  'Wayne TTY',
#  'Mysore Mateo',
#  'Bridgeport Katie',
#  'Glendale Mildred',
#  'Dooley Venice',
#  'Margaret Kathleen',
#  'Merrimack Kettering',
#  'Ruanda Libreville',
#  'Albany Springfield',
#  'Cadillac Laurentian',
#  'June Augustus',
#  'Boltzmann Churchillian',
#  'Olsen Neva',
#  'Kruse Hatteras',
#  'Mirfak Strauss',
#  'Corvus Lamar',
#  'Bonaventure Kresge',
#  'Bloomington Heisenberg',
#  'Justinian Aesop',
#  'Gerald Knoxville',
#  'Tokyo Giuseppe',
#  'Abramson Ida',
#  'Lilian Hempstead',
#  'Hoover Clifton',
#  'Vermont Oldsmobile',
#  'Roxbury Roman',
#  'Oberlin Auerbach',
#  'Oberlin Catalina',
#  'British Woodstock',
#  'Reykjavik Everett',
#  'Morristown FCC',
#  'Travis Salk',
#  'Franciscan Peru',
#  'Peugeot Hans',
#  'Fernando Sammy',
#  'Sweeney Wilkinson',
#  'Brahmsian Trumbull',
#  'Tucson Seneca',
#  'Filipino Hayes',
#  'Pickering Hispanic',
#  'Brian Isis',
#  'Chesapeake Bern',
#  'Clausius Bergland',
#  'USAF Eileen',
#  'McDougall Konrad',
#  'Konrad Utah',
#  'Nikko Judd',
#  'Edinburgh Amoco',
#  'GM Ned',
#  'NASA Africa',
#  'Mrs Sepoy',
#  'Bobbie Nicholson',
#  'Bridgewater Vaudois',
#  'McGowan Alpert',
#  'Asilomar Mozart',
#  'Gus Ehrlich',
#  'Hardin Corbett',
#  'Brookhaven Malawi',
#  'WAC Milwaukee',
#  'Pakistan Whalen',
#  'Riemannian Lydia',
#  'Masonite Stetson',
#  'Pocono Everett',
#  'Freetown Sam',
#  'Cochrane Cramer',
#  'Catherine Egan',
#  'NW Doppler',
#  'Czech Comanche',
#  'Oklahoma Annapolis',
#  'Einstein Viking',
#  'Chelsea Tracy',
#  'Antietam Rio',
#  'Chinatown Gino',
#  'Suzanne Holst',
#  'Miguel Riga',
#  'Polyhymnia Ullman',
#  'Felix Rosa',
#  'Parkinson Noreen',
#  'Hanukkah Bushnell',
#  'Ottoman Marlowe',
#  'Muscovy David',
#  'Kronecker CO',
#  'Mae Puerto',
#  'Savoyard Portia',
#  'Savonarola Blatz',
#  'Enid Batavia',
#  'Orion Anabel',
#  'Sloane Schwartz',
#  'Twombly Elijah',
#  'Boeotia Mansfield',
#  'Penh Vulcan',
#  'Poisson Huxtable',
#  'Abe TEX',
#  'Lila Cardiff',
#  'Hesperus Taylor',
#  'Polyphemus Honda',
#  'Blackburn Conway',
#  'Iranian Kirchoff',
#  'Ralph Irrawaddy',
#  'Norse Rubaiyat',
#  'Zambia Halloween',
#  'Selkirk Veda',
#  'Cambodia Allentown',
#  'Landis Nat',
#  'Duffy Harold',
#  'Dacca James',
#  'Bali Clapeyron',
#  'Laidlaw Conway',
#  'Bethlehem Socrates',
#  'Haney Everett',
#  'Scorpio Leila',
#  'Waller Bryant',
#  'Jacksonville Frazier',
#  'Elisha Ecole',
#  'SCM Alcestis',
#  'Maltese Morton',
#  'Atwood Helen',
#  'McGill Caputo',
#  'Persephone Canaan',
#  'BEMA Enrico',
#  'Egan Heinz',
#  'Hoffman Atwater',
#  'Amadeus Janos',
#  'Burma Aztecan',
#  'Callisto Sheehan',
#  'Leopold Fredrickson',
#  'Orpheus Friday',
#  'Pease Bosporus',
#  'Mohammed Irrawaddy',
#  'Elysee Voltaire',
#  'Seth Chinatown',
#  'Littleton Passover',
#  'Mendel Acadia',
#  'Goa Wayne',
#  'Prometheus Antaeus',
#  'Shoshone MD',
#  'Liz Aquila',
#  'Polyhymnia Ernie',
#  'Hyannis Decatur',
#  'Alabamian Breton',
#  'Auckland Riemannian',
#  'Seagram Ness',
#  'NCR Ackley',
#  'Bellingham Becky',
#  'Janus Bosporus',
#  'Balboa Candide',
#  'Pickering Maurice',
#  'Baylor Mudd',
#  'Carruthers Teheran',
#  'Dorothea Reinhold',
#  'Emmett Goodyear',
#  'Andromeda Lucretius',
#  'Lucian Kevin',
#  'Pentecost NY',
#  'BEMA Lamarck',
#  'Corey Dane',
#  'Shiloh Hermite',
#  'Salk Philip',
#  'Westinghouse Denmark',
#  'Conrad Xavier',
#  'Essex Hobbes',
#  'Epsom Cody',
#  'Felicia Cuvier',
#  'Gail Ragusan',
#  'Gloriana Bellini',
#  'Hesperus Paraguay',
#  'Oresteia Dickerson',
#  'Wooster Strickland',
#  'Rutherford Topsy',
#  'Grumman Hansen',
#  'Eben Whippany',
#  'Irene Northrup',
#  'Simmons Abramson',
#  'Youngstown Virgo',
#  'Downey Lowell',
#  'Pavlovian Carbone',
#  'Malagasy Josiah',
#  'Tarrytown Knowlton',
#  'Medici Assam',
#  'Schuylkill KY',
#  'Brasilia Whitney',
#  'Dobbs Nouakchott',
#  'Clausen Gwen',
#  'Steve Raymond',
#  'Stanley Cheryl',
#  'Massey Langley',
#  'Bundestag Kramer',
#  'Wilkinson Compagnie',
#  'July Jacobite',
#  'Bach Dostoevsky',
#  'Delia Antoine',
#  'Marquette Talmudic',
#  'GU Steinberg',
#  'Wellesley Kaskaskia',
#  'Hershey Cruickshank',
#  'Chad Bacchus',
#  'Neil Salvatore',
#  'Monroe Higgins',
#  'Montana Edwina',
#  'Tel Moghul',
#  'Legendre Macon',
#  'Nora Oldsmobile',
#  'Lenny Osborne',
#  'Christensen Galatia',
#  'Midwest NH',
#  'Parkinson Putnam',
#  'Compagnie Piccadilly',
#  'Montague Northumberland',
#  'Cecropia Tibetan',
#  'Methuen Wichita',
#  'Knott Appalachia',
#  'Dixon Iroquois',
#  'Cushing Galloway',
#  'Ron Maurine',
#  'Turing Avernus',
#  'Tutenkhamon Borneo',
#  'Adelia Southampton',
#  'Schneider Nazarene',
#  'Debussy Benares',
#  'Escherichia Tibetan',
#  'Moines Habib',
#  'Gertrude Algeria',
#  'Pavlovian Chattanooga',
#  'Dutch Gilead',
#  'Andorra Guthrie',
#  'Euripides CDC',
#  'Marcel Vito',
#  'Shiloh Macadamia',
#  'Enos Buckley',
#  'Kuwait Roman',
#  'Mendelian Asiatic',
#  'Iroquois Squibb',
#  'Byrne Miami',
#  'Dar Melcher',
#  'Johannesburg Winslow',
#  'Montclair Farnsworth',
#  'Marx Katmandu',
#  'Hindi UN',
#  'Titan Mann',
#  'Hermosa Tioga',
#  'Percival Tulane',
#  'Nippon Meier',
#  'Siegfried Handel',
#  'Tuesday Ashmolean',
#  'Hornblower Babcock',
#  'Asuncion Judas',
#  'Gemma Hewitt',
#  'Bolshevik Dionysian',
#  'Lieberman Steele',
#  'Christoph Culver',
#  'Pritchard Garibaldi',
#  'Jura Atwater',
#  'Copperfield Andre',
#  'Hanoverian Virgo',
#  'Cruickshank Schroedinger',
#  'Canis SSE',
#  'Monterey Knott',
#  'Salle Allan',
#  'Arnold Steuben',
#  'Twombly Arnold',
#  'SW Oshkosh',
#  'Nielson Durrell',
#  'Inman Assyriology',
#  'Haitian Transylvania',
#  'Drummond Gillespie',
#  'Lansing Fermi',
#  'NH Dewey',
#  'Angeline Irish',
#  'Dorcas Webb',
#  'McKenna Alexis',
#  'Cezanne Olav',
#  'Genesco Thompson',
#  'Ndjamena Cameroon',
#  'Batchelder Cromwellian',
#  'Osaka Smyrna',
#  'Laplace Roman',
#  'Dominican Lathrop',
#  'Mecca Weller',
#  'Eunice Kant',
#  'Siegmund Martinson',
#  'Bombay Amtrak',
#  'Olaf Bernadine',
#  'Barrett Vinci',
#  'Thruway Floridian',
#  'Jon Shreveport',
#  'Lin Menlo',
#  'Ernst Maryland',
#  'Taylor Michele',
#  'Langmuir Kidde',
#  'Tacitus Versailles',
#  'Gwen Canaan',
#  'Saunders Davies',
#  'Joaquin Davy',
#  'Octavia EPA',
#  'Pakistani Punic',
#  'Stygian Eratosthenes',
#  'Thetis Walgreen',
#  'Jarvin Laocoon',
#  'Alexandra Yosemite',
#  'Jacobite Adolph',
#  'Shannon Elizabethan',
#  'IQ Eaton',
#  'Josephine Phipps',
#  'Jill Alabama',
#  'Baird Nazism',
#  'Amharic Roberto',
#  'Sylvania Antioch',
#  'Draconian Doherty',
#  'Trevelyan Pitt',
#  'Clifton Andre',
#  'Sydney Chao',
#  'Burch Australia',
#  'Draco Russell',
#  'Chou Johnny',
#  'Phobos Maseru',
#  'Monty Aida',
#  'Verlag USGS',
#  'Regulus Bailey',
#  'Doris Sylvania',
#  'Mafioso Topsy',
#  'Coffey Sanderson',
#  'Gustav Tuscaloosa',
#  'Zachary Leon',
#  'Asilomar Ludlow',
#  'Compagnie McKee',
#  'Viet Eleanor',
#  'Frances Barlow',
#  'Athabascan Albany',
#  'Cessna Lethe',
#  'Jonas Jo',
#  'Leavenworth Francoise',
#  'Feldman Nielson',
#  'Argentinian Alexandra',
#  'Firestone Christine',
#  'Hera Toledo',
#  'Agamemnon Osiris',
#  'Leslie Potomac',
#  'Ayers Colette',
#  'Durkin Halsey',
#  'Draco Eva',
#  'Della Mona',
#  'Yankee Sam',
#  'Ashmolean Tuscan',
#  'Puritan Hieronymus',
#  'Jennie Potts',
#  'Abe Pusey',
#  'Alabamian Frye',
#  'McMahon Thorpe',
#  'Staley Jungian',
#  'TX Bridgetown',
#  'Lockheed FCC',
#  'Antigone Crusoe',
#  'October Laidlaw',
#  'Garrett Mississippian',
#  'Kuhn Kingsbury',
#  'Stuttgart Peking',
#  'Beirut Toby',
#  'Lauderdale Schwartz',
#  'Greenbriar Toledo',
#  'Kankakee Shylock',
#  'Nanette Hendrick',
#  'Passover Eulerian',
#  'Carmen Orono',
#  'Drury Statler',
#  'Marlboro YWCA',
#  'Stuart Mendelssohn',
#  'Buenos Lysenko',
#  'Austria O',
#  'Sydney Kaufman',
#  'Dairylea Jim',
#  'Inca Scythia',
#  'Corinth Denton',
#  'Ostrander Ekstrom',
#  'Duma Heathkit',
#  'Matson Clinton',
#  'Duncan Pizarro',
#  'Stockholm Thessaly',
#  'Kessler Cohen',
#  'Parsifal Bator',
#  'Seidel Middlesex',
#  'Huber Greenbriar',
#  'Tennessee Lowell',
#  'Sinai Gillette',
#  'McKinney Gujarat',
#  'Alexis Oslo',
#  'Spica Lise',
#  'SUNY Nakayama',
#  'Bator Ryan',
#  'Missouri Belize',
#  'Raytheon Edward',
#  'Schuster Crispin',
#  'Levis USA',
#  'Bourbaki Mac',
#  'Laughlin Pete',
#  'Gothic Rufus',
#  'TVA Laredo',
#  'Lockheed Somalia',
#  'Buddhism Balinese',
#  'Moran Champaign',
#  'Cunningham Pelham',
#  'Janos Michael',
#  'Martinson Farnsworth',
#  'Sumner Brock',
#  'Monteverdi Gruyere',
#  'Valois Benedict',
#  'Nevins Hewett',
#  'Rushmore Ethel',
#  'Genevieve Mississippi',
#  'Pliny Citroen',
#  'Landis O',
#  'Ruanda Gabriel',
#  'Saskatchewan Rensselaer',
#  'Rothschild Tutankhamen',
#  'Oneida Cathy',
#  'Nullstellensatz Culver',
#  'Melinda Galilean',
#  'Sadie Arachne',
#  'Templeton LIFO',
#  'MacDougall Geigy',
#  'Lovelace Keller',
#  'Cossack Abelson',
#  'Petersen Putnam',
#  'Bohr Cochrane',
#  'Kowalewski Asuncion',
#  'Rumford Pasteur',
#  'Oberlin Armour',
#  'Teddy Mafia',
#  'Vermont Noetherian',
#  'Caine Ndjamena',
#  'Cummins Decca',
#  'Heinz Salvatore',
#  'Tegucigalpa Ephraim',
#  'Norfolk Motorola',
#  'Hester Melanesia',
#  'Ariadne Creole',
#  'Alger Ullman',
#  'Isabella Shanghai',
#  'Blvd Knutson',
#  'Dusenberg Monica',
#  'Beauregard Paulo',
#  'Haugen Squibb',
#  'Galbreath Devonshire',
#  'Bernard Jamaica',
#  'Plymouth Yeager',
#  'Adelia Loeb',
#  'Pancho Shylock',
#  'Stratford Magdalene',
#  'Gabon Sikkim',
#  'Jove Amelia',
#  'Felice DOD',
#  'Montmartre Kenneth',
#  'Japanese Cantabrigian',
#  'Heublein Parthenon',
#  'Lisbon Bonaventure',
#  'Artemis Reagan',
#  'Montevideo Barlow',
#  'Recife Euterpe',
#  'Dow Cramer',
#  'Pentateuch Lubbock',
#  'MacDougall Bergman',
#  'Giuliano Prentice',
#  'Mary Pict',
#  'Agway Landis',
#  'Logan Jimmie',
#  'Lange Sydney',
#  'Balfour GMT',
#  'Marianne Thomistic',
#  'Rockland Allegra',
#  'Lucerne Romania',
#  'Libreville Stapleton',
#  'Clark Ankara',
#  'Hanukkah Buddhist',
#  'Cumberland Hilton',
#  'Kiwanis MD',
#  'Donna Mahoney',
#  'Labrador Ervin',
#  'SCM Nottingham',
#  'Interpol Scot',
#  'Lancaster Syracuse',
#  'Goldstein MD',
#  'Agricola Ruanda',
#  'Emmanuel Ursa',
#  'Zellerbach Bateman',
#  'Blackstone Janus',
#  'Marcy Alsatian',
#  'Karamazov Aeneas',
#  'MacDougall Toyota',
#  'Feldman Sigmund',
#  'Schwartz Theresa',
#  'Leland Latvia',
#  'Vesuvius Transite',
#  'Laredo McCoy',
#  'Nabisco Wisconsin',
#  'Torrance Recife',
#  'Siemens Peru',
#  'Picasso Luftwaffe',
#  'Armenia Mac',
#  'Crimea Iowa',
#  'Hutchinson Copperfield',
#  'Delhi Whittier',
#  'Quantico Valkyrie',
#  'Alphonse Cambrian',
#  'Bundoora Palatine',
#  'Curran Dante',
#  'Leopold Arturo',
#  'Salton KS',
#  'Flagstaff Colette',
#  'Wilhelmina Horace',
#  'Nordhoff Monteverdi',
#  'Jutland Pliocene',
#  'Augustus Annette',
#  'Spokane Atwood',
#  'Rhode Cobb',
#  'Wang Scorpio',
#  'Dearborn Hindustan',
#  'Douglass Masonite',
#  'Amarillo Bausch',
#  'Rodney Ranier',
#  'Herculean Kashmir',
#  'Judith Celia',
#  'Micky Oslo',
#  'Andrea Hansel',
#  'Courtney Rutgers',
#  'Missy Bamako',
#  'Millard Sarasota',
#  'Alberich Millie',
#  'Cobol Hillel',
#  'Lubell Drury',
#  'Steuben Douglass',
#  'Horus Heidelberg',
#  'Margaret Belize',
#  'Erie Copernicus',
#  'Foss Gutenberg',
#  'Chautauqua Syracuse',
#  'Elijah Nicholas',
#  'Dacca Wyoming',
#  'Yellowknife Hague',
#  'Durkee Hanson',
#  'Zanzibar Electra',
#  'IRS UN',
#  'Salish Luzon',
#  'Austria Lausanne',
#  'Gould Levine',
#  'Hepburn Warsaw',
#  'Vincent Cajun',
#  'Orion Talmudic',
#  'Odysseus Buttrick',
#  'Julie Martinez',
#  'Sheppard Egan',
#  'Nan Janos',
#  'Thuban U',
#  'Selkirk Hesse',
#  'Hitchcock Riviera',
#  'Noah Yucatan',
#  'Meier Finn',
#  'Frey Varian',
#  'Bismark Tiber',
#  'Romanesque Conestoga',
#  'Hindustan Giovanni',
#  'Paraguayan Capetown',
#  'Aquinas Milwaukee',
#  'Ashmolean Tel',
#  'Leighton Stan',
#  'Freetown Ponchartrain',
#  'Tito Reginald',
#  'Cole Boston',
#  'Boeotia Hans',
#  'Nantucket MIT',
#  'Mr Marcy',
#  'Raphael Gruyere',
#  'Bryn Northrup',
#  'Gunderson Bangui',
#  'Donna Bellatrix',
#  'Bernadine January',
#  'Whelan Hinman',
#  'Jacobite Miguel',
#  'Lagrange Madagascar',
#  'Semite Mexico',
#  'Fordham Tirana',
#  'Madrid Kingsley',
#  'Icarus Theodore',
#  'Sam Marlowe',
#  'Banach Lars',
#  'NCR Wadsworth',
#  'Verde Barton',
#  'Aeneas Effie',
#  'Sussex DOD',
#  'Hibernia Wilkes',
#  'Peloponnese Telefunken',
#  'Domingo Krieger',
#  'Haugen Tamil',
#  'Wagner Othello',
#  'Mary Bernhard',
#  'Piraeus Vinci',
#  'Kay Pandora',
#  'Gilead Houston',
#  'Brandeis GPO',
#  'Hollywood Gerhard',
#  'Burma Kafka',
#  'Morton Cadillac',
#  'Goleta Barnum',
#  'Rowley Adkins',
#  'Alexandre Ellis',
#  'Creon Nietzsche',
#  'Eastwood Bathurst',
#  'Doneck Eloise',
#  'Abel Jessie',
#  'Sheraton Millard',
#  'Gail Maggie',
#  'Percival Parr',
#  'Metcalf Maltese',
#  'Isadore Storey',
#  'Guggenheim Tutenkhamon',
#  'Gauguin Nostradamus',
#  'Tobago Oedipus',
#  'Nikolai Ecole',
#  'Kline Lexington',
#  'Nellie Hopkinsian',
#  'McMillan Georgia',
#  'Riemann Allegra',
#  'Annale Artie',
#  'Bobbie Maurice',
#  'Dailey Vincent',
#  'Royce Starkey',
#  'GNP Olympia',
#  'Alex Uris',
#  'Angelina Bimini',
#  'Bayda Sikkim',
#  'Englander Triangulum',
#  'RPM Jaime',
#  'Guilford Poughkeepsie',
#  'Bulgaria Prague',
#  'Hellenic Capitoline',
#  'Picasso Ashley',
#  'Houston Ragusan',
#  'Columbus Rabin',
#  'Schlesinger Confucian',
#  'Decatur Illinois',
#  'Quirinal Bernadine',
#  'Donald Olivetti',
#  'PhD Stearns',
#  'Spaulding Antares',
#  'Appleby Edgerton',
#  'Cain Glenn',
#  'Poland Clarke',
#  'Zaire Gaberones',
#  'Diogenes Enid',
#  'Laidlaw Ku',
#  'Israeli Blackman',
#  'Singapore Vanderpoel',
#  'Tuesday Gabriel',
#  'Benson Shearer',
#  'Connally Puritan',
#  'Melissa Shaffer',
#  'Rutgers Cuvier',
#  'Bella Stromberg',
#  'Woodlawn Chadwick',
#  'Cambridge SUNY',
#  'Langley Algeria',
#  'Jimenez Tokyo',
#  'Zachary Gunther',
#  'Brussels Nadine',
#  'Aristotle Emory',
#  'Percival Oldsmobile',
#  'Peking Wheller',
#  'Ott Chalmers',
#  'Cuba Sweeney',
#  'Thule Aires',
#  'Suffolk Somerset',
#  'Alsatian BP',
#  'Lindholm Erastus',
#  'McNally Sylvia',
#  'Herbert Agnew',
#  'FL Cambridge',
#  'Sudan Barnes',
#  'Hispanic Laughlin',
#  'Amman Napoleonic',
#  'David Nanette',
#  'Fayette Zanzibar',
#  'Biltmore Claus',
#  'Hutchison Merrill',
#  'Algeria Bismark',
#  'Eumenides Whalen',
#  'Reese Canadian',
#  'Africa Guardia',
#  'POBox Olaf',
#  'TN Bethlehem',
#  'Conant Florentine',
#  'Prague Karp',
#  'Helvetica Sheridan',
#  'Israeli Herbert',
#  'Muzo Muenster',
#  'Athens Ghana',
#  'Stanhope Stanford',
#  'Maier Zoroaster',
#  'Steven Melbourne',
#  'Aries Bolton',
#  'Ganges Tiffany',
#  'Sieglinda Ian',
#  'Harvey Luftwaffe',
#  'Cody Papua',
#  'Calkins Nobel',
#  'Wilkes Eldon',
#  'Eunice Roger',
#  'Mach Conant',
#  'Wyatt Anita',
#  'Dakar Qatar',
#  'Danielson Seton',
#  'Aiken TRW',
#  'Latin Illinois',
#  'Virginia Stauffer',
#  'Baffin Theodore',
#  'Durkee Alexandre',
#  'Heuser Ethel',
#  'Jorgenson Afghan',
#  'IL Brisbane',
#  'Keaton Sanskrit',
#  'Moravia Hewitt',
#  'Stephanie Aruba',
#  'Benedict Angles',
#  'Spirogyra Kenneth',
#  'Pascal Hempstead',
#  'Denton Eleazar',
#  'Wolff SIAM',
#  'Penh Ayers',
#  'Argentine Dutchman',
#  'Ellen Josephine',
#  'Stefan Rosalie',
#  'Waite Ezra',
#  'Cameroun Dostoevsky',
#  'Irma Punjabi',
#  'Plainfield Hanoverian',
#  'Milan Gallup',
#  'Cleveland Skopje',
#  'Blum Smalley',
#  'Christensen Kirkpatrick',
#  'Parmesan Helmut',
#  'Millie Blomquist',
#  'Anselm Hawley',
#  'Ontario Hadrian',
#  'Anglican Edinburgh',
#  'Trumbull FCC',
#  'Brett Ptolemy',
#  'Leslie Mr',
#  'Dutton Liz',
#  'Des Alsatian',
#  'Seymour Norma',
#  'Wabash Eliot',
#  'Sparkman Ilona',
#  'Lyon Bourbaki',
#  'Houghton Hetty',
#  'Schmitt Pitney',
#  'Lucian Wang',
#  'Hester Antietam',
#  'Madagascar MacArthur',
#  'VA Middlebury',
#  'Clare Gertrude',
#  'Gilmore Turing',
#  'Societe Capitoline',
#  'Cramer Wolfgang',
#  'Merriam Dayton',
#  'Catalina Aylesbury',
#  'Curran Cicero',
#  'Wrigley Wilson']

# %% [markdown]
# ### Pull all the passwords from the data variable

# %%
passwords = re.findall('Password: ([1,9]{2}\w*)', data)
passwords
# Out:
# ['99shelve266kenton',
#  '91pestilential551corp',
#  '11anticipate822maya',
#  '91heresy288gibraltar',
#  '91joey338margery',
#  '11wok317keaton',
#  '11whoop327sumatra',
#  '11culvert617dana',
#  '99referential770kajar',
#  '19hormonal868susie',
#  '91handwritten483ella',
#  '99swordtail654monongahela',
#  '11w418stalin',
#  '99prosecution347carrara',
#  '11collapsible460yukon',
#  '11dirt863johnston']

# %% [markdown]
# ### Pull all the addresses from the data variable

# %%
address = re.findall('Address: ([0-9]{3}\s\w*\s\w*,\s\w*\s\w*,\s[1-9]{5})', data)
address
# Out:
# ['558 Bennington Ave, Fredericksburg SC, 12416',
#  '963 Thoreau Blvd, Eulerian NE, 39355',
#  '829 Helsinki Blvd, Ragusan SD, 26412',
#  '579 Bodleian Ave, TVA SC, 35621',
#  '576 Haddad Ave, January ID, 86795',
#  '460 Java Lane, Brest UT, 88578',
#  '717 Samoa Lane, Burundi GA, 49851',
#  '919 PepsiCo Ave, Heusen VA, 26844',
#  '504 Mexico Lane, Loire TX, 41691',
#  '107 Thule Lane, Hamal DC, 58599',
#  '196 Hermann Blvd, Maseru IA, 46266',
#  '658 Sebastian Lane, Schlitz ID, 67774',
#  '497 Azerbaijan Blvd, Fogarty MS, 83527',
#  '988 Australis Court, Macassar TX, 22939',
#  '469 Armageddon Blvd, Moresby UT, 76115',
#  '351 Borroughs Blvd, Chapman PA, 79869',
#  '626 Hellenic Court, Elsinore MA, 79765',
#  '481 Porto Blvd, McDougall WV, 41767',
#  '397 Cinderella Blvd, Balboa HI, 33261',
#  '230 Burgundian Court, Clausius IL, 16864',
#  '216 GPO Court, Gobi IA, 87274',
#  '770 Cruickshank Blvd, Hurd ID, 37897',
#  '271 Hollingsworth Lane, Elsevier WI, 92693',
#  '583 NC Ave, Skopje WY, 55534',
#  '681 Asilomar Court, Diego SC, 62738',
#  '712 Argus Ave, Sussex OH, 22555',
#  '585 Antoine Court, Hendrickson IN, 76896',
#  '563 Kikuyu Court, Miami WV, 12866',
#  '881 Methuselah Lane, Helmholtz NH, 61311',
#  '747 Christian Blvd, Hiatt MN, 13539',
#  '746 Lusaka Lane, Agnes NC, 24948',
#  '286 Dora Court, Jordan WV, 22398',
#  '449 Brady Lane, Bergland NE, 48918',
#  '205 Joanna Court, Humphrey AR, 51484',
#  '355 Osiris Ave, Morse CO, 13135',
#  '270 Ginn Ave, Simon MT, 94884',
#  '190 Ramsey Blvd, Bartok CO, 55399',
#  '531 Berra Lane, Triceratops NE, 95794',
#  '938 Spokane Blvd, Hanover UT, 59429',
#  '251 Henrietta Court, Cottrell AR, 27539',
#  '727 Boreas Blvd, Quakeress TX, 82653',
#  '219 Ontario Lane, Mitchell ID, 67861',
#  '987 Honduras Lane, Antioch LA, 15446',
#  '695 Michelin Blvd, Pergamon WY, 82641',
#  '775 Puerto Ave, Nichols OK, 88596',
#  '263 Farmington Court, Cruickshank AK, 13168',
#  '829 Comanche Ave, Matsumoto MS, 62481',
#  '828 Shmuel Court, Java FL, 83941',
#  '714 Bissau Blvd, McFarland MD, 56973',
#  '431 Abbott Court, Krebs SC, 84845',
#  '462 Bulgaria Blvd, Vreeland NC, 17769',
#  '613 Hodges Ave, Marvin NJ, 96518',
#  '164 Mississippi Blvd, Indiana SD, 66186',
#  '809 Nicholas Ave, Dido WV, 74752',
#  '966 Leander Lane, Islamabad UT, 83187',
#  '193 Beauregard Court, Mediterranean TN, 93764',
#  '565 Cygnus Ave, Dubhe UT, 57483',
#  '863 Mozart Ave, Semitic IA, 57768',
#  '503 Ike Blvd, Biggs NJ, 58111',
#  '892 Carthage Lane, Kruse NE, 95314',
#  '477 Atkinson Court, England MO, 93565',
#  '876 Haines Ave, Barcelona CO, 13241',
#  '177 YMCA Lane, Fijian IA, 26582',
#  '405 Fenton Lane, Jerome AK, 98389',
#  '418 Leeuwenhoek Court, Donovan CO, 39833',
#  '135 Gilead Blvd, Veronica TN, 46886',
#  '815 Reub Ave, Britten IA, 82583',
#  '478 Thetis Blvd, Fischer MA, 72134',
#  '166 Sybil Ave, Egan MO, 79753',
#  '268 Giacomo Court, Shapiro SC, 16328',
#  '889 Monterey Blvd, Dane SC, 71118',
#  '590 Jim Lane, Knauer NC, 99586',
#  '302 Burundi Blvd, Rene ID, 98346',
#  '226 Kalmuk Court, Aegean IN, 63236',
#  '952 Payne Lane, Whittaker MS, 75194',
#  '537 Brownell Lane, Pusan SC, 62965',
#  '849 Erato Lane, Jewish MT, 82262',
#  '516 Apollonian Court, USA LA, 28327',
#  '576 Huffman Ave, McGowan MN, 29932',
#  '251 Denver Blvd, Halley CA, 48794',
#  '628 Caviness Blvd, Gorham MD, 99371',
#  '828 NIMH Blvd, Acton AZ, 22865',
#  '823 Herman Blvd, Brock MA, 99129',
#  '454 Jupiter Blvd, Koch AK, 82787',
#  '491 McDonald Court, Sabine NY, 92126',
#  '110 Mesopotamia Lane, Davis AZ, 49834',
#  '707 Fritz Blvd, Igor ME, 38229',
#  '267 Larsen Blvd, Knapp KY, 92835',
#  '827 Fanny Lane, Osiris PA, 13818',
#  '544 Gaberones Court, Zomba TX, 44395',
#  '596 Thurman Blvd, Scotia NC, 71774',
#  '900 Monmouth Court, Nielsen MA, 25779',
#  '216 Poughkeepsie Court, Levis OH, 26113',
#  '986 Marcello Court, Balkan PA, 13966',
#  '326 Rome Lane, Sci FL, 78297',
#  '980 Harrisburg Court, Frau CA, 38162',
#  '155 Novak Blvd, Mel AR, 87421',
#  '143 Dillon Blvd, Paz OH, 43616',
#  '383 Rockland Blvd, Corbett ID, 14847',
#  '227 Galway Ave, Sprague RI, 19684',
#  '607 Vito Lane, Algiers IA, 96398',
#  '534 Poland Ave, Ito NV, 92414',
#  '486 Huxtable Lane, Finley AZ, 97836',
#  '222 Bohemia Ave, Bimini AK, 66635',
#  '147 Harris Ave, William NC, 56583',
#  '828 Dixie Court, Callisto PA, 65767',
#  '492 Walden Court, Foss MA, 36847',
#  '932 Schroeder Lane, MN TX, 63466',
#  '307 IEEE Lane, Magnuson NJ, 72548',
#  '141 Colombia Court, Signor ME, 22276',
#  '898 Southey Blvd, Shepard SD, 65174',
#  '872 Patterson Blvd, Saskatoon TX, 97323',
#  '913 Cruickshank Blvd, Verde UT, 42672',
#  '796 Stephen Lane, Middleton WI, 99487',
#  '822 Carbone Lane, Liberia LA, 65948',
#  '755 TN Ave, Dhabi MT, 87411',
#  '174 Essex Blvd, Yankee SC, 11338',
#  '912 Japan Blvd, Nelson WY, 54775',
#  '993 Calgary Lane, Rena MT, 67718',
#  '634 Aruba Ave, Dodd WY, 17897',
#  '517 Cesare Ave, Parthia AR, 68515',
#  '833 Euripides Blvd, Anderson MA, 54936',
#  '608 Rutledge Blvd, TTL FL, 31525',
#  '779 Yuki Lane, Ekstrom MI, 26959',
#  '176 Candide Ave, Buchwald DC, 78556',
#  '154 Chandigarh Ave, Kaplan AZ, 97131',
#  '381 Schroedinger Court, Dirichlet TX, 57886',
#  '657 Newcastle Ave, McNulty HI, 94366',
#  '317 Nevada Blvd, Enid MN, 87524',
#  '708 Pierson Blvd, Lizzie NY, 84751',
#  '327 Essen Ave, Parrish VT, 39425',
#  '856 Lois Court, Winnetka DE, 93833',
#  '206 Pygmalion Lane, Horowitz PA, 66212',
#  '698 Judd Blvd, Antwerp NV, 85522',
#  '473 Matsumoto Blvd, Celanese FL, 92714',
#  '867 Gardner Lane, Goethe NY, 62759',
#  '747 Yemen Court, Gaines ID, 92368',
#  '215 Tutankhamen Ave, Paine MN, 28663',
#  '304 Alhambra Court, Proserpine MD, 52635',
#  '241 Dora Blvd, Gemini MS, 45466',
#  '967 Riemann Ave, Tektronix MI, 58155',
#  '452 Ulster Court, Kernighan VT, 66887',
#  '483 Greer Blvd, Lorinda AK, 48278',
#  '677 Madeline Blvd, Hebrew LA, 55194',
#  '582 Brisbane Lane, Chautauqua KY, 97292',
#  '410 Olav Ave, Adolph OH, 26576',
#  '467 Yellowknife Blvd, Carrie CO, 74816',
#  '383 Webb Court, Wolcott ND, 97813',
#  '311 Rae Blvd, Margaret DE, 59979',
#  '136 Ulysses Ave, Kathy NC, 95622',
#  '102 Pisces Lane, Orestes LA, 84728',
#  '956 Bloomfield Blvd, Benelux AR, 67256',
#  '841 Sol Lane, Lauderdale IL, 63792',
#  '665 Leeuwenhoek Court, Rousseau VA, 79776',
#  '354 GAO Ave, Huron VT, 55746',
#  '568 Priscilla Lane, Bakersfield MD, 62688',
#  '609 Janos Court, Cobol HI, 32323',
#  '646 Salton Ave, Weinstein WY, 51241',
#  '152 Ft Court, Prof SC, 58711',
#  '472 Gretchen Court, Coleman MA, 17778',
#  '771 Po Lane, Barry OH, 48942',
#  '228 IL Court, Jupiter LA, 54961',
#  '774 Verne Lane, Bois SC, 96314',
#  '480 FDA Blvd, Curtis ID, 73284',
#  '967 Mathews Lane, Genevieve ID, 93593',
#  '637 Malta Blvd, Wrigley CT, 51527',
#  '852 Soc Court, Romania MS, 33458',
#  '267 Yaqui Court, Donald MI, 65587',
#  '562 Seton Court, Montgomery AR, 59541',
#  '681 Hottentot Ave, Mephistopheles GA, 51932',
#  '864 Chomsky Court, Severn TX, 42812',
#  '271 McConnell Lane, Christie AK, 72933',
#  '665 Poe Lane, Byrd MD, 72748',
#  '848 Adler Court, Elliott MN, 56884',
#  '194 Dayton Lane, Erastus AK, 31474',
#  '522 Callahan Blvd, Sommerfeld FL, 22925',
#  '403 Ovid Ave, Tyler SD, 27646',
#  '856 Shearer Ave, Alberto VA, 59193',
#  '127 Healy Blvd, Leona SD, 85687',
#  '430 Gutenberg Lane, Thayer VT, 22138',
#  '192 Ralph Lane, Fiberglas FL, 19314',
#  '649 FCC Blvd, Horton FL, 56528',
#  '623 Smythe Blvd, Salina SC, 25322',
#  '934 Precambrian Court, Barnes AR, 95357',
#  '174 Hurst Ave, Daimler IL, 97589',
#  '928 Peugeot Lane, Guiana OK, 98535',
#  '119 Episcopalian Blvd, Malawi LA, 69631',
#  '713 Hoff Court, Chiang NH, 27696',
#  '692 Signora Court, Catherine OK, 31247',
#  '487 Burnham Lane, Bermuda MD, 56758',
#  '557 Annalen Ave, Sorensen MA, 38393',
#  '753 Cedric Court, Juanita RI, 68229',
#  '161 Cushman Court, Lyle KS, 96565',
#  '461 NW Blvd, PM NV, 54621',
#  '711 Truk Ave, Jordan CO, 42766',
#  '997 Maureen Ave, Benedikt LA, 16513',
#  '955 Everglade Lane, Driscoll WA, 12659',
#  '116 DC Blvd, Friesland VT, 12118',
#  '520 Lehigh Lane, Kidde ND, 32633',
#  '377 Holst Court, Carlo ND, 78385',
#  '808 Phillip Court, Dee MO, 51875',
#  '209 Dorothea Ave, Donaldson KS, 74559',
#  '908 Rafferty Blvd, Kellogg NM, 42248',
#  '217 Olivia Ave, Maggie CO, 47726',
#  '195 Precambrian Blvd, Annapolis CT, 23145',
#  '220 Moriarty Lane, Kilgore AR, 74345',
#  '964 Chad Ave, Quebec MT, 51788',
#  '964 Krueger Court, Persia UT, 82127',
#  '161 Mullen Ave, Nebuchadnezzar AK, 95439',
#  '154 Catskill Ave, Braniff VT, 77461',
#  '575 Walt Lane, Transite VA, 25487',
#  '624 Burroughs Blvd, McGowan IN, 75668',
#  '902 Kendall Ave, Huston KY, 75823',
#  '712 Celtic Court, Hudson AK, 25948',
#  '811 Dallas Court, Lowe TN, 68268',
#  '202 Midwest Court, Davidson KY, 28915',
#  '364 Wilma Court, Hankel AK, 76987',
#  '142 Kaufman Lane, Rd SC, 31575',
#  '980 Valletta Lane, Robinson NE, 26455',
#  '532 Fitchburg Blvd, Cessna OH, 12746',
#  '652 Kingsbury Blvd, USIA MS, 63182',
#  '397 ITT Lane, Oakland ME, 19627',
#  '550 Paulo Blvd, Kabuki GA, 83247',
#  '466 Kelsey Blvd, ICC UT, 15858',
#  '940 Orr Ave, Malabar FL, 99971',
#  '501 Royce Court, Goren NM, 19722',
#  '724 Helmut Court, Catherwood VA, 51562',
#  '413 Ifni Lane, Pakistani ID, 22742',
#  '616 Machiavelli Court, Jacobus IA, 57422',
#  '617 Nottingham Lane, Derbyshire IN, 16733',
#  '363 Pict Blvd, DOD KS, 52579',
#  '677 Vance Ave, Tennyson UT, 27982',
#  '955 Janet Ave, McDermott WY, 17894',
#  '338 MacKenzie Ave, Lind NM, 18156',
#  '669 Mueller Lane, Essen MD, 87363',
#  '340 Burke Lane, Aquinas WY, 54356',
#  '241 Willis Blvd, Barbados MS, 84414',
#  '742 Westfield Ave, Elliott TN, 52875',
#  '618 Mohr Lane, USA OR, 65194',
#  '992 Betelgeuse Ave, Cezanne SC, 34556',
#  '662 Vicksburg Blvd, SST WV, 93819',
#  '745 Mazda Blvd, Indoeuropean OH, 74443',
#  '900 Bilbao Lane, Williamsburg MI, 33755',
#  '778 Appleton Court, McGrath RI, 12777',
#  '446 Faustian Court, Edinburgh CT, 92218',
#  '289 Manila Lane, Calcutta SC, 69889',
#  '319 Montague Blvd, PTA AZ, 63613',
#  '224 Merriam Ave, Kline LA, 91521',
#  '886 Cincinnati Court, Moreland WI, 66296',
#  '934 Colgate Blvd, Mobil MD, 84276',
#  '196 Aristotelean Court, Hausa UT, 63529',
#  '135 Oakley Blvd, Aldrich NE, 94199',
#  '336 Scotty Lane, Shipley ID, 79647',
#  '425 Bolshevism Ave, Samuelson WY, 58768',
#  '804 Duluth Court, Dublin UT, 54485',
#  '346 Apollo Lane, Leviticus IN, 33221',
#  '891 Cessna Blvd, Brumidi SC, 13782',
#  '632 Quinn Lane, Fullerton DE, 24127',
#  '347 Noetherian Ave, Juneau KS, 85283',
#  '504 Flanagan Lane, NY UT, 34977',
#  '377 Marion Ave, Alfredo KY, 69332',
#  '470 Thorpe Ave, Calvin ID, 84416',
#  '795 Conway Ave, Egyptology ID, 76882',
#  '651 Jewell Lane, Decca AK, 88214',
#  '141 Tenneco Ave, Cooley TX, 29425',
#  '480 Kalmuk Lane, Elton OK, 31986',
#  '401 Percy Ave, Alger MT, 17123',
#  '226 Congolese Court, Suzanne VT, 59816',
#  '225 Andover Lane, Worthington NJ, 63131',
#  '711 Britten Lane, Hera KS, 89831',
#  '235 Decca Court, Hannibal NV, 88721',
#  '451 Friesland Blvd, Calvert TN, 46115',
#  '804 Fiji Lane, Lyon NE, 57871',
#  '614 Beardsley Lane, Periclean SD, 32695',
#  '110 Istvan Blvd, Crispin DE, 48949',
#  '100 Rd Ave, Platonism IN, 63621',
#  '979 Friedrich Lane, Procrustes CO, 12358',
#  '323 Atlanta Ave, Riyadh IA, 43142',
#  '211 Aiken Court, Thai RI, 71378',
#  '123 Hamlin Blvd, Uris GA, 73859',
#  '431 Serpens Court, Basel NH, 58573',
#  '941 Rosetta Blvd, Antilles NV, 64715',
#  '249 Buddhism Ave, Kennedy IA, 76495',
#  '712 Flanagan Court, Hollywood NJ, 89878',
#  '635 Samoa Lane, Atreus MN, 73188',
#  '535 Joseph Ave, NATO ME, 23293',
#  '515 Bunsen Blvd, Pickford CT, 13557',
#  '258 Fogarty Blvd, Martinson TN, 51842',
#  '422 Ithaca Lane, Alberto WI, 34761',
#  '722 Hiatt Ave, Gothic GA, 36755',
#  '174 Pelham Blvd, Wong OR, 84894',
#  '527 Java Lane, Deneb OK, 75697',
#  '199 Hayes Court, MPH CT, 75424',
#  '832 Jude Lane, Jacques IN, 58335',
#  '104 Stratford Ave, Menzies CO, 25859',
#  '339 UNESCO Blvd, Boniface NH, 75129',
#  '677 Pocono Ave, Pancho MT, 97213',
#  '876 Kowloon Blvd, Pizarro KS, 78673',
#  '405 Midas Blvd, FBI CA, 32671',
#  '328 NH Lane, Nagasaki DC, 12861',
#  '908 Teledyne Blvd, Buenos WY, 59689',
#  '833 MIT Court, Sorenson DC, 87262',
#  '469 Kalmuk Blvd, Maya AK, 13959',
#  '861 Culver Lane, Rene PA, 35994',
#  '932 Tina Blvd, Pensacola MN, 69288',
#  '679 Carmichael Lane, Czerniak GA, 47825',
#  '918 Annalen Court, Vietnamese UT, 95637',
#  '219 Shawnee Ave, Alec NY, 24644',
#  '451 Tomlinson Ave, Dorothea ID, 76364',
#  '202 Worthington Ave, Jeannie DE, 61989',
#  '403 Melanie Court, Orville OR, 95575',
#  '275 Portuguese Lane, RPM MI, 96314',
#  '268 Falmouth Lane, Paraguayan NY, 36929',
#  '234 Vaduz Ave, Aeneas SD, 36391',
#  '758 Buena Blvd, Saratoga NE, 59459',
#  '638 Uris Blvd, Doric ID, 48275',
#  '615 Boeotia Lane, Blackburn MD, 69521',
#  '601 Angeline Lane, Hutchinson MI, 31595',
#  '682 Elgin Court, Minnie PA, 39949',
#  '562 Bergson Blvd, Jorgensen SD, 51137',
#  '926 Maxine Ave, Dnieper ID, 57475',
#  '142 Starkey Court, Sicily DC, 24463',
#  '340 Mendel Court, Bolshevik NE, 73241',
#  '460 Lowry Lane, Dis CT, 79344',
#  '177 Ostrander Court, Welles ID, 54337',
#  '347 McPherson Ave, Prometheus DE, 86596',
#  '877 Goodrich Ave, Gunther KY, 35294',
#  '476 Beardsley Court, Barbara MT, 87764',
#  '790 Kruger Ave, Greek MS, 74711',
#  '777 TOEFL Ave, Gillette UT, 27811',
#  '321 Lufthansa Lane, Sanhedrin AZ, 93147',
#  '684 Joanna Lane, Andrew AK, 83421',
#  '215 Cornell Lane, Christopher ID, 61829',
#  '385 Goren Ave, Somerville TX, 55452',
#  '562 Whitehorse Blvd, Cypriot LA, 95396',
#  '709 Nan Blvd, Sheraton NE, 53748',
#  '695 Hempstead Lane, Smythe PA, 59363',
#  '260 Gino Lane, Catskill NH, 34585',
#  '558 Louisiana Blvd, Tarzan OR, 34649',
#  '780 Percy Court, Boniface NH, 96365',
#  '458 Natchez Lane, USGS ND, 37221',
#  '443 Yellowknife Ave, Wyner WA, 83127',
#  '472 Anabel Lane, Lagrange MD, 41248',
#  '690 Kafka Ave, Blvd WY, 66424',
#  '909 Alexandria Ave, Aleutian OK, 42848',
#  '300 Eagan Ave, Norse KS, 77273',
#  '778 Libya Ave, Gus IA, 48575',
#  '186 Micky Ave, Kremlin NM, 24824',
#  '271 Waterloo Ave, Berlioz ID, 51525',
#  '195 Frau Court, Cohen RI, 96573',
#  '245 Dempsey Blvd, Kidde CO, 47786',
#  '254 Ernst Blvd, Pareto FL, 57429',
#  '271 Salton Blvd, Bobbie OR, 46152',
#  '363 Osaka Court, Clausen KY, 54584',
#  '333 Escherichia Blvd, Madrid ND, 83566',
#  '773 Sonora Ave, Munson IN, 29377',
#  '448 Marceau Court, Hanna VA, 84844',
#  '334 Anaheim Lane, Scarlatti NV, 36527',
#  '588 Ackerman Ave, Mycenae PA, 72148',
#  '624 Hutchins Blvd, Leonid ND, 45191',
#  '386 Gimbel Court, Angie HI, 49637',
#  '603 Engle Blvd, Verna KY, 11295',
#  '848 Carson Ave, Clara WA, 21722',
#  '316 Hoboken Court, Alcott OK, 66553',
#  '761 Denton Lane, Della MO, 85469',
#  '413 Petersburg Blvd, Forsythe SD, 76172',
#  '729 Reagan Ave, Copenhagen MN, 27811',
#  '188 Fullerton Ave, Caputo WI, 59594',
#  '838 Newfoundland Blvd, Palmolive DE, 74785',
#  '758 Cardiff Court, Waals IA, 37119',
#  '767 Alton Lane, Dada FL, 61531',
#  '148 Scotsmen Lane, Allis CA, 67149',
#  '754 Maddox Blvd, Shoshone NV, 52293',
#  '432 Antwerp Ave, Arlene AZ, 18861',
#  '982 Merle Lane, Friedrich KS, 54861',
#  '538 Morgan Lane, Icarus NV, 23334',
#  '245 Southampton Blvd, Hoyt NC, 44942',
#  '230 Berkowitz Ave, Zulu WY, 43658',
#  '836 Ronald Court, Blythe DC, 79914',
#  '901 Reginald Lane, Menorca MT, 79395',
#  '755 Nina Lane, Sumatra WV, 83411',
#  '330 Valois Ave, Islam VT, 24185',
#  '144 Furman Ave, Fisk WV, 19163',
#  '409 Rayleigh Ave, Selfridge NC, 39991',
#  '175 Hispanic Court, Palestine SC, 36348',
#  '802 Dorado Lane, Hyman LA, 48328',
#  '178 Hanna Lane, McDermott DC, 51625',
#  '252 Euridyce Ave, Sancho CA, 75815',
#  '799 Xavier Lane, Shipley IL, 32342',
#  '410 Johnston Ave, Francoise NH, 23876',
#  '851 Scarsdale Blvd, Hermosa TN, 29946',
#  '749 Mickey Ave, Caucasian MN, 19455',
#  '772 Schuyler Ave, Thea WV, 99773',
#  '681 Wolfgang Court, Heisenberg PA, 29421',
#  '155 Iranian Court, Rand MS, 34621',
#  '982 Nicodemus Blvd, Greenblatt OK, 67847',
#  '571 Polaroid Ave, Altair SC, 95593',
#  '519 Johanna Blvd, Romeo TX, 61435',
#  '280 NRC Ave, Holst PA, 35161',
#  '428 Finn Blvd, Senora HI, 52733',
#  '675 Hewlett Blvd, Bonaventure NJ, 53989',
#  '621 Santa Blvd, Bingham CT, 29316',
#  '523 Glaswegian Lane, Goode MO, 95425',
#  '421 EPA Blvd, Foote WA, 14381',
#  '694 Santo Court, Velasquez IN, 62848',
#  '237 Greenberg Blvd, NTIS WY, 85341',
#  '837 McAdams Ave, Latvia KS, 61686',
#  '140 Chao Ave, Halverson NC, 73941',
#  '911 Barrington Ave, Allan NV, 88634',
#  '681 Dutton Blvd, David NM, 82881',
#  '351 Laue Lane, Knickerbocker OK, 38564',
#  '961 Argonne Ave, Dorset IN, 18154',
#  '562 Thalia Ave, Hodges OR, 34528',
#  '482 Thompson Lane, Seaborg OH, 45194',
#  '501 Rowley Court, Floridian WY, 97631',
#  '335 Wilhelmina Court, Heraclitus CA, 88736',
#  '715 Yankton Blvd, Glenn IA, 16157',
#  '534 Antioch Blvd, Ranier DC, 57188',
#  '746 Zagreb Court, Preston WI, 47947',
#  '947 Procrustes Court, Nicodemus NV, 67829',
#  '227 Laurie Ave, Barbados CO, 94754',
#  '746 Dunbar Court, Brie MS, 53411',
#  '671 Laocoon Lane, Ft NY, 16665',
#  '493 Bulgaria Lane, Thermofax LA, 67418',
#  '428 Albania Ave, Suzuki CA, 34672',
#  '131 Britannic Ave, Aquarius AR, 79713',
#  '466 Kettering Lane, Greenberg MI, 53899',
#  '321 Maggie Blvd, Marcel WA, 24168',
#  '796 Harlem Lane, Gujarat AK, 66458',
#  '165 Polyphemus Lane, Holland WV, 41579',
#  '313 Veneto Lane, Injun GA, 38967',
#  '723 Corcoran Blvd, Siberia DE, 95864',
#  '202 NBC Court, Tuscarora OH, 98579',
#  '407 Leigh Court, JACM CT, 61231',
#  '477 Accra Lane, Walden NV, 64368',
#  '980 Brownell Blvd, Terra TN, 16425',
#  '262 Botswana Lane, Oldenburg SC, 92788',
#  '665 Storey Ave, Thursday AZ, 56685',
#  '164 Everglade Blvd, Muir OK, 64726',
#  '498 McDonnell Ave, Irene AZ, 15423',
#  '262 Livermore Ave, Rachmaninoff MO, 78271',
#  '173 Prof Lane, July OR, 17893',
#  '940 Igor Ave, Glenn NV, 39513',
#  '416 Antares Ave, Perseus NH, 38692',
#  '161 Emilio Ave, Porto WV, 66599',
#  '360 Gibson Ave, Balinese DE, 94868',
#  '771 RI Lane, Pyrex IN, 19943',
#  '618 Fischer Court, Parmesan NH, 31154',
#  '613 Manila Ave, Winifred WV, 26331',
#  '404 Truk Blvd, Crawford NM, 72731',
#  '605 Harvard Court, Rothschild WV, 99739',
#  '850 Smalley Ave, Enrico FL, 71289',
#  '311 Baffin Ave, Diebold SC, 92559',
#  '188 Volta Ave, Gaulle WY, 25577',
#  '526 Elysee Ave, Aries ME, 85245',
#  '619 Albuquerque Court, Glasgow MT, 78691',
#  '466 Bodleian Court, Buddha ND, 39943',
#  '325 Whitlock Blvd, Joan NE, 56673',
#  '288 Luxembourg Lane, NASA ND, 83845',
#  '145 Mont Ave, Warsaw VT, 26376',
#  '285 Gordian Ave, Anthony GA, 13782',
#  '249 Hieronymus Blvd, Monash LA, 84537',
#  '381 Belgian Ave, Lubell LA, 46536',
#  '520 Letitia Blvd, Citroen FL, 96349',
#  '829 Matthew Ave, Draconian AK, 89579',
#  '543 Katowice Court, Steuben MD, 69492',
#  '520 Westinghouse Lane, Dalton OK, 67121',
#  '305 Vulcan Blvd, Metzler NJ, 88252',
#  '760 Carolingian Blvd, Stetson NE, 88983',
#  '699 Mudd Lane, Kyle ND, 22266',
#  '430 Keller Ave, Emmett GA, 46989',
#  '869 Andromeda Blvd, Welch OR, 62365',
#  '909 Lilian Ave, Hobbs CT, 72392',
#  '255 Martinson Lane, Anatole NE, 85259',
#  '547 Tanganyika Blvd, Byrne PA, 78128',
#  '512 Morton Blvd, Hamlin WI, 16449',
#  '446 Freudian Lane, Sam FL, 97899',
#  '255 Deneb Ave, Carolinian TX, 41197',
#  '137 Pease Ave, Jude IL, 72213',
#  '980 Lagrange Ave, Ovid SC, 74223',
#  '976 Schenectady Court, Lionel IA, 49643',
#  '706 Klaus Ave, Minnesota NC, 66176',
#  '101 Dominick Blvd, Christy NV, 69493',
#  '864 Punjab Lane, Banach AR, 47997',
#  '997 Guelph Ave, Slocum FL, 88548',
#  '139 Carlson Ave, Seton LA, 47183',
#  '902 Euphrates Blvd, Rhodes NH, 63493',
#  '199 Nellie Court, Strom AZ, 46955',
#  '658 Dunbar Court, Jacksonville OH, 25661',
#  '192 Graff Ave, Stefan GA, 84139',
#  '913 Lamar Ave, Carson KS, 46397',
#  '180 Rosenthal Blvd, Claude NV, 26712',
#  '706 Julie Lane, Russell MD, 17431',
#  '374 Barrington Court, Gaston KY, 74927',
#  '946 TWX Lane, Etruscan AZ, 31421',
#  '666 Busch Ave, Erwin AZ, 72781',
#  '778 Camelot Court, Analects WI, 67664',
#  '127 Huntington Court, Tennyson KS, 95244',
#  '154 Crowley Court, Marceau MN, 76661',
#  '348 Gilbertson Ave, Burt WY, 25457',
#  '833 Jim Ave, Europe KY, 99315',
#  '850 Toledo Court, Escherichia AR, 29531',
#  '805 Marcus Blvd, Rome VA, 14872',
#  '452 Cambodia Ave, Romano NJ, 84538',
#  '779 Mt Ave, Dorothy VA, 72782',
#  '214 Germany Blvd, Ghana NH, 14927',
#  '118 Calvin Blvd, Spaniard NC, 94956',
#  '226 Barcelona Ave, Athens UT, 15839',
#  '691 Rubin Court, Hippocratic UT, 68893',
#  '165 Amman Ave, Maryland AK, 21178',
#  '806 Hattie Court, Debussy SD, 26628',
#  '552 Ludlow Court, Cobol LA, 63215',
#  '116 Raphael Lane, Fiske NH, 17947',
#  '717 Nelson Ave, Socratic SC, 32239',
#  '514 Steen Blvd, TRW MT, 98449',
#  '587 Vladivostok Blvd, Floridian AZ, 93551',
#  '156 Irma Lane, Yokohama MA, 93158',
#  '874 Howe Court, Theodosian HI, 93766',
#  '747 Hines Lane, Sweeney UT, 89154',
#  '692 Formosa Blvd, Selkirk AZ, 67995',
#  '500 Selkirk Blvd, Vietnamese SD, 84437',
#  '342 Valois Ave, Sweeney IN, 65869',
#  '619 Benedikt Blvd, Vivaldi MS, 68898',
#  '598 Mercedes Blvd, Fiske MS, 23587',
#  '478 Arturo Ave, Galveston AK, 35636',
#  '703 Guinevere Lane, Maharashtra NV, 74934',
#  '561 Venice Lane, Buddhist DE, 58866',
#  '505 Assyriology Ave, Aurelius DC, 35886',
#  '285 Wyner Lane, Haugen WY, 25733',
#  '240 Nikolai Court, Levine CT, 54125',
#  '787 Barcelona Court, Rickettsia IL, 21914',
#  '450 Addis Blvd, Charlotte AK, 33357',
#  '408 Englishman Lane, Negroes MI, 69982',
#  '359 Minos Ave, Washburn SD, 32327',
#  '193 Greenberg Ave, Rastus FL, 85454']

# %% [markdown]
# ### Which state had the most addresses in your data?

# %%
state = []
#state += re.findall('Address: [0-9]{3}\s\w*\s\w*,\s\w*\s(\w*)', data)
state += re.findall('\s[A-Z]{2},', data)
pd.value_counts(state)[0:1]
# Out:
#  AK,    29
# dtype: int64

# %% [markdown]
# ### Do we have any famous people in our data?
# #### Check to see if there are any user names that are also city/street names

# %%
names = re.findall('Name:\s(\w*\s+\w*)', data)
streets = re.findall('Address:\s[0-9]*\s+(\w*)\s', data)
city = re.findall('Address:\s+\w*\s+\w*\s+\w*,\s+(\w*)\s+\w*,\s+\w*', data)

fame = {}

for name in names:
    for cty in city:
        if cty in names:
            fame[name] = [cty]
    for strt in streets:
        if strt in name:
            fame[name] = [strt]
print [x for x in fame]
# Out:
# ['BEMA Lamarck', 'Starr Shearer', 'Andromeda Lucretius', 'Britannica Aitken', 'Mendel Acadia', 'SCM Nottingham', 'Petersen Putnam', 'McGill Caputo', 'Escherichia Tibetan', 'IL Brisbane', 'Riemann Allegra', 'Auckland Riemannian', 'Lieberman Steele', 'Roxbury Roman', 'Poland Clarke', 'Lovelace Keller', 'Firestone Christine', 'Leslie Potomac', 'Bulgaria Prague', 'Hellenic Capitoline', 'Simmons Timex', 'Clausius Bergland', 'Mary Pict', 'Minerva Episcopalian', 'Foss Gutenberg', 'Brandeis GPO', 'Ralph Irrawaddy', 'NW Doppler', 'NCR Ackley', 'Jason Pompeii', 'Geoffrey Rhodesia', 'Montague Northumberland', 'Orion Anabel', 'Hepburn Warsaw', 'Hera Toledo', 'Lenny Osborne', 'Merrimack Kettering', 'Asilomar Mozart', 'Greenbriar Toledo', 'Semite Mexico', 'Nan Janos', 'Corvus Lamar', 'Heublein Parthenon', 'Meier Finn', 'Margaret Belize', 'Julie Martinez', 'Lila Cardiff', 'Pickering Hispanic', 'Adlerian Croix', 'Genevieve Mississippi', 'Thule Aires', 'Selkirk Veda', 'Hispanic Laughlin', 'McMahon Thorpe', 'Quantico Valkyrie', 'Pickering Maurice', 'Rockland Allegra', 'Siegmund Martinson', 'Elysee Voltaire', 'Monterey Knott', 'Ontario Hadrian', 'Cruickshank Schroedinger', 'Lagrange Madagascar', 'Ernst Maryland', 'Heinz Salvatore', 'Gail Maggie', 'Lockheed Somalia', 'Stygian Eratosthenes', 'McMillan Georgia', 'Lockheed FCC', 'Maier Zoroaster', 'Alberich Millie', 'Japanese Cantabrigian', 'Selkirk Hesse', 'Octavia EPA', 'Maltese Morton', 'Penh Vulcan', 'Egan Heinz', 'Leighton Stan', 'Raphael Gruyere', 'Angeline Irish', 'Cambodia Allentown', 'Janos Michael', 'Ellen Josephine', 'Colgate Agee', 'Inman Assyriology', 'Manville Ziegler', 'TVA Laredo', 'Peugeot Hans', 'TN Bethlehem', 'Nevins Hewett', 'Chad Bacchus', 'Montmartre Kenneth', 'Alex Uris', 'Albuquerque Floridian', 'Riemannian Lydia', 'Euripides CDC', 'Rothschild Tutankhamen', 'Glendale Mildred', 'Yellowknife Hague', 'Dooley Venice', 'Micky Oslo', 'Hoffman Atwater', 'Dearborn Hindustan', 'Zealand Kettering', 'Nullstellensatz Culver', 'Essex Hobbes', 'Burma Kafka', 'Youngstown Virgo', 'Jarvin Laocoon', 'Christensen Kirkpatrick', 'Jennie Potts', 'Josephine Phipps', 'Osaka Smyrna', 'Laidlaw Conway', 'Martinson Farnsworth', 'Moines Habib', 'Jimenez Tokyo', 'Buddhism Balinese', 'Polyphemus Honda', 'Delia Antoine', 'Amman Napoleonic', 'Denton Eleazar', 'Hershey Cruickshank', 'Lancaster Syracuse', 'Durkee Hanson', 'Bethlehem Socrates', 'Boeotia Mansfield', 'Dorcas Webb', 'McKenna Alexis', 'Camelot Hollingsworth', 'Herculean Kashmir', 'Polyhymnia Ullman', 'Marquette Talmudic', 'Bismark Tiber', 'Filipino Hayes', 'Matson Clinton', 'Siemens Peru', 'Hindustan Giovanni', 'Duffy Harold', 'Danielson Seton', 'Salton KS', 'Spokane Atwood', 'Abe Pusey', 'Tobago Oedipus', 'Nippon Meier', 'Caine Ndjamena', 'Gino Patti', 'NCR Erich', 'Cezanne Olav', 'Thetis Walgreen', 'Merriam Dayton', 'Morristown FCC', 'Olsen Neva', 'Monteverdi Gruyere', 'Schuylkill KY', 'Bolshevik Dionysian', 'Montclair Farnsworth', 'Schlesinger Confucian', 'Beauregard Paulo', 'Wilhelmina Horace', 'Aries Bolton', 'Dutton Liz', 'Adelia Southampton', 'Dacca Wyoming', 'Asilomar Ludlow', 'Leopold Arturo', 'Chinatown Gino', 'NCR Wadsworth', 'David Nanette', 'Mafioso Topsy', 'Mendelian Asiatic', 'Dorothea Reinhold', 'Bobbie Nicholson', 'Gilead Houston', 'Baffin Theodore', 'Morton Cadillac', 'Conrad Xavier', 'Lilian Hempstead', 'Schofield Mennonite', 'Stratford Magdalene', 'Midwest NH', 'Freetown Ponchartrain', 'NH Dewey', 'Czech Comanche', 'McKinney Gujarat', 'Savoyard Portia', 'Dusenberg Monica', 'Polyhymnia Ernie', 'Stephanie Aruba', 'Zachary Leon', 'Iranian Kirchoff', 'Cessna Lethe', 'Dairylea Jim', 'Cramer Wolfgang', 'Christensen Galatia', 'Agamemnon Osiris', 'Rowley Adkins', 'Trumbull FCC', 'Montana Edwina', 'Blum Smalley', 'Rutherford Topsy', 'Parmesan Helmut', 'Garrett Mississippian', 'Nikolai Ecole', 'Boeotia Hans', 'Logan Jimmie', 'Pascal Hempstead', 'Balboa Candide', 'Poisson Huxtable', 'Elijah Nicholas', 'Chou Johnny', 'Sydney Kaufman', 'Tit ...

# %% [markdown]
# ### What is the value count of the zipcodes in your addresses?

# %%
## save printing a huge list, heres the top ten.
zips = re.findall('\d{5}', data)
zipcodes = pd.Series(zips)
zipcodes.value_counts()[:10]
# Out:
# 98307    2
# 13782    2
# 28018    2
# 33105    2
# 27811    2
# 96314    2
# 23876    1
# 22084    1
# 44502    1
# 82881    1
# dtype: int64
